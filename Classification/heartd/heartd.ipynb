# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
sns.set_style('darkgrid')

# %%
df=pd.read_csv('e://desktop/data/heart.csv')
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# # identifying variable

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %% [markdown]
# # basic statistics

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df.min()
# Out:
# age          29.0
# sex           0.0
# cp            0.0
# trestbps     94.0
# chol        126.0
# fbs           0.0
# restecg       0.0
# thalach      71.0
# exang         0.0
# oldpeak       0.0
# slope         0.0
# ca            0.0
# thal          0.0
# target        0.0
# dtype: float64

# %%
df.max()
# Out:
# age          77.0
# sex           1.0
# cp            3.0
# trestbps    200.0
# chol        564.0
# fbs           1.0
# restecg       2.0
# thalach     202.0
# exang         1.0
# oldpeak       6.2
# slope         2.0
# ca            4.0
# thal          3.0
# target        1.0
# dtype: float64

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# no null values

# %% [markdown]
# # data exploration

# %%
df['target'].value_counts()
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %%
features = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal','target']
for i in features:
    plt.figure(figsize=(10,10))
    plt.hist(df[i])
    plt.xlabel(i)
    plt.title(i)

# %%
plt.figure(figsize=(10,10))
sns.histplot(x=df['age'], hue=df['sex'])
plt.xlabel('sex')
plt.title('sex histplot')
# Out:
# Text(0.5, 1.0, 'sex histplot')

# %%
df['target'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
plt.figure(figsize=(10,10))
plt.scatter(x=df.age[df.target==1], y=df.thalach[(df.target==1)], color="red")
plt.scatter(x=df.age[df.target==0], y=df.thalach[(df.target==0)], color="green")
plt.legend(["Disease", "Not Disease"])
plt.xlabel("Age")
plt.ylabel("Maximum Heart Rate")
plt.show()
#maximum heart rate  vs age  disease and not disease scatter plot

# %%
plt.figure(figsize=(10,10))
plt.scatter(x=df.age[df.target==1], y=df.trestbps[(df.target==1)], c="red")
plt.scatter(x=df.age[df.target==0], y=df.trestbps[(df.target==0)], c="green")
plt.legend(["Disease", "Not Disease"])
plt.xlabel("Age")
plt.ylabel("Resting Blood Pressure")
plt.show()
#blood pressure  vs age  disease and not disease scatter plot

# %%
plt.figure(figsize=(10,10))
plt.scatter(x=df.age[df.target==1], y=df.chol[(df.target==1)], c="red")
plt.scatter(x=df.age[df.target==0], y=df.chol[(df.target==0)], c="green")
plt.legend(["Disease", "Not Disease"])
plt.xlabel("Age")
plt.ylabel("cholestrol ")
plt.show()

# %%
plt.figure(figsize=(20,20))

plt.subplot(2,3,1)
sns.distplot(df['age']).set_title('Age')

plt.subplot(2,3,2)
sns.distplot(df['chol']).set_title('Chol')

plt.subplot(2,3,3)
sns.distplot(df['thalach']).set_title('Thalach')

plt.subplot(2,3,4)
sns.distplot(df['oldpeak']).set_title('Oldpeak')

plt.subplot(2,3,5)
sns.distplot(df['trestbps']).set_title('Resting Blood Pressure')

#dist plot of all countable features
# Out:
# Text(0.5, 1.0, 'Resting Blood Pressure')

# %%
plt.figure(figsize=(20,5))
sns.barplot(x="age", y="thalach", data=df, hue="target")
plt.show()

# %% [markdown]
# heatmap to check correlation

# %%
plt.figure(figsize=(10,10)) 
sns.heatmap(df.corr(), annot=True)
plt.show()
# to check correlationship

# %% [markdown]
# # preprocessing data

# %%
from sklearn.model_selection import train_test_split as tts
from sklearn.preprocessing import StandardScaler
y= df["target"]   #depedent variable 
x = df.drop('target',axis=1)   #independent variable 
xtr,xtst,ytr,ytst = tts(x, y, test_size=0.15)    #splitting data 85% vs 15%
scaler=StandardScaler()      #data standardization 
xtr=scaler.fit_transform(xtr)
xtst=scaler.fit_transform(xtst)

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC   #support vector classifier 
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
svc =  SVC()
svc.fit(xtr, ytr)
print('training score',svc.score(xtr,ytr))
yhat= svc.predict(xtst)
print("confussion matrix")
print(confusion_matrix(ytst, yhat))    #ytst is actual result and yhat is predicted result 
print("-------------------------------------------")
print("Accuracy of Support Vector Classifier:",accuracy_score(ytst, yhat))
print("-------------------------------------------")
print(classification_report(ytst,yhat))
# Out:
# training score 0.914396887159533
# confussion matrix
# [[17  5]
#  [ 1 23]]
# -------------------------------------------
# Accuracy of Support Vector Classifier: 0.8695652173913043
# -------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.94      0.77      0.85        22
#            1       0.82      0.96      0.88        24
#
#     accuracy                           0.87        46
#    macro avg       0.88      0.87      0.87        46
# weighted avg       0.88      0.87      0.87        46

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
tr=DecisionTreeClassifier()
tr.fit(xtr,ytr)
print('training score',tr.score(xtr,ytr))
yhat=tr.predict(xtst)
# Out:
# training score 1.0

# %%
print(classification_report(yhat,ytst))
print('##################')
print(confusion_matrix(yhat,ytst))
print('accuracy score',accuracy_score(yhat,ytst))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.62      0.70        24
#            1       0.67      0.82      0.73        22
#
#     accuracy                           0.72        46
#    macro avg       0.73      0.72      0.72        46
# weighted avg       0.73      0.72      0.72        46
#
# ##################
# [[15  9]
#  [ 4 18]]
# accuracy score 0.717391304347826

# %% [markdown]
# # logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

lr=LogisticRegression()
lr.fit(xtr,ytr)
print('training',lr.score(xtr,ytr))
yhat=lr.predict(xtst)
print('testing',lr.score(xtst,ytst))
# Out:
# training 0.8560311284046692
# testing 0.782608695652174

# %%
print(classification_report(yhat,ytst))
print(confusion_matrix(yhat,ytst))
print('accuracy score',accuracy_score(yhat,ytst))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.71      0.75        21
#            1       0.78      0.84      0.81        25
#
#     accuracy                           0.78        46
#    macro avg       0.78      0.78      0.78        46
# weighted avg       0.78      0.78      0.78        46
#
# [[15  6]
#  [ 4 21]]
# accuracy score 0.782608695652174

# %% [markdown]
# # naive bays

# %%
from sklearn.naive_bayes import GaussianNB
gnb=GaussianNB()
gnb.fit(xtr,ytr)
print('traingin score',gnb.score(xtr,ytr))
# Out:
# traingin score 0.8404669260700389

# %%
yhat=gnb.predict(xtst)
gnb.score(xtst,ytst)
# Out:
# 0.8913043478260869

# %%
print(classification_report(yhat,ytst))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.85      0.87        20
#            1       0.89      0.92      0.91        26
#
#     accuracy                           0.89        46
#    macro avg       0.89      0.89      0.89        46
# weighted avg       0.89      0.89      0.89        46

# %%
print(confusion_matrix(yhat,ytst))
# Out:
# [[17  3]
#  [ 2 24]]

# %%
print('accuracy score',accuracy_score(yhat,ytst))
# Out:
# accuracy score 0.8913043478260869
