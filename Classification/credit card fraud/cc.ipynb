# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('e://desktop/data/cc.csv')
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
df.head(10)
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
# 5  C10006  1809.828751           1.000000    1333.28              0.00
# 6  C10007   627.260806           1.000000    7091.01           6402.63
# 7  C10008  1823.652743           1.000000     436.20              0.00
# 8  C10009  1014.926473           1.000000     861.49            661.49
# 9  C10010   152.225975           0.545455    1281.60           1281.60
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                   95.40      0.000000             0.166667
# 1                    0.00   6442.945483             0.000000
# ...

# %%
df.tail(10)
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 8940  C19181   130.838554           1.000000     591.24              0.00
# 8941  C19182  5967.475270           0.833333     214.55              0.00
# 8942  C19183    40.829749           1.000000     113.28              0.00
# 8943  C19184     5.871712           0.500000      20.90             20.90
# 8944  C19185   193.571722           0.833333    1012.73           1012.73
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 8940                  591.24      0.000000             1.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %% [markdown]
# visual analysis

# %%
df.columns
# Out:
# Index(['CUST_ID', 'BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES',
#        'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
#        'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
#        'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
#        'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
#        'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE'],
#       dtype='object')

# %%
num_col=['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES',
       'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
       'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
       'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
       'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
       'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE']
for i in num_col:
    plt.figure(figsize=(10,10))
    sns.distplot(df[i])
    plt.show()

# %%
for i in num_col:
    plt.figure(figsize=(10,10))
    sns.boxplot(df[i])
    plt.show()

# %% [markdown]
# # null value treatment

# %%
df.isnull().any()
# Out:
# CUST_ID                             False
# BALANCE                             False
# BALANCE_FREQUENCY                   False
# PURCHASES                           False
# ONEOFF_PURCHASES                    False
# INSTALLMENTS_PURCHASES              False
# CASH_ADVANCE                        False
# PURCHASES_FREQUENCY                 False
# ONEOFF_PURCHASES_FREQUENCY          False
# PURCHASES_INSTALLMENTS_FREQUENCY    False
# CASH_ADVANCE_FREQUENCY              False
# CASH_ADVANCE_TRX                    False
# PURCHASES_TRX                       False
# CREDIT_LIMIT                         True
# PAYMENTS                            False
# MINIMUM_PAYMENTS                     True
# PRC_FULL_PAYMENT                    False
# TENURE                              False
# dtype: bool

# %%
df['CREDIT_LIMIT'].isnull().sum()
# Out:
# 1

# %%
df['MINIMUM_PAYMENTS'].isnull().sum()
# Out:
# 313

# %%
df['CREDIT_LIMIT'].fillna(df['CREDIT_LIMIT'].mean(),inplace=True)
df['MINIMUM_PAYMENTS'].fillna(df['MINIMUM_PAYMENTS'].mean(),inplace=True)

# %%
df.isnull().any()
# Out:
# CUST_ID                             False
# BALANCE                             False
# BALANCE_FREQUENCY                   False
# PURCHASES                           False
# ONEOFF_PURCHASES                    False
# INSTALLMENTS_PURCHASES              False
# CASH_ADVANCE                        False
# PURCHASES_FREQUENCY                 False
# ONEOFF_PURCHASES_FREQUENCY          False
# PURCHASES_INSTALLMENTS_FREQUENCY    False
# CASH_ADVANCE_FREQUENCY              False
# CASH_ADVANCE_TRX                    False
# PURCHASES_TRX                       False
# CREDIT_LIMIT                        False
# PAYMENTS                            False
# MINIMUM_PAYMENTS                    False
# PRC_FULL_PAYMENT                    False
# TENURE                              False
# dtype: bool

# %%
from sklearn.cluster import KMeans
sse=[]
for i in range(2,30):
    km=KMeans(n_clusters=i)
    km.fit(df[num_col])
    sse.append(km.inertia_)
plt.figure(figsize=(10,10))
plt.plot(sse)
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
mn=MinMaxScaler()
scaled=mn.fit_transform(df[num_col])
scaled
# Out:
# array([[2.14779454e-03, 8.18182000e-01, 1.94536779e-03, ...,
#         1.82564563e-03, 0.00000000e+00, 1.00000000e+00],
#        [1.68169097e-01, 9.09091000e-01, 0.00000000e+00, ...,
#         1.40344791e-02, 2.22222000e-01, 1.00000000e+00],
#        [1.31026136e-01, 1.00000000e+00, 1.57662475e-02, ...,
#         8.20961806e-03, 0.00000000e+00, 1.00000000e+00],
#        ...,
#        [1.22871936e-03, 8.33333000e-01, 2.94456089e-03, ...,
#         1.07843629e-03, 2.50000000e-01, 0.00000000e+00],
#        [7.06688341e-04, 8.33333000e-01, 0.00000000e+00, ...,
#         7.29475795e-04, 2.50000000e-01, 0.00000000e+00],
#        [1.95717777e-02, 6.66667000e-01, 2.22932216e-02, ...,
#         1.15527021e-03, 0.00000000e+00, 0.00000000e+00]])

# %%
km=KMeans(n_clusters=8)
yhat=km.fit_predict(scaled)
df['cluster']=yhat

# %%
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
df1=df[df['cluster']==0]
df2=df[df['cluster']==1]
df3=df[df['cluster']==2]
df4=df[df['cluster']==3]
df5=df[df['cluster']==4]
df6=df[df['cluster']==5]

plt.figure(figsize=(10,10))

sns.countplot(x=df['cluster'])


plt.show()

# %%
km.cluster_centers_.shape
# Out:
# (8, 17)

# %%
cluster_centers=mn.inverse_transform(km.cluster_centers_)
cluster_centers
# Out:
# array([[1.45697944e+03, 9.28074370e-01, 1.06996994e+03, 2.65516495e+02,
#         8.04767620e+02, 6.65769036e+02, 9.31400072e-01, 9.16662803e-02,
#         8.90758424e-01, 8.96262411e-02, 2.15475451e+00, 2.26177750e+01,
#         3.83196948e+03, 1.46307431e+03, 1.26688866e+03, 5.91397756e-02,
#         1.16171535e+01],
#        [1.68409369e+03, 9.39121853e-01, 8.45455880e+02, 5.18674303e+02,
#         3.27749857e+02, 7.46594226e+02, 5.00676513e-01, 2.09885666e-01,
#         3.13015657e-01, 1.06211469e-01, 2.77575277e+00, 1.07503962e+01,
#         4.43928829e+03, 1.42091504e+03, 8.70927426e+02, 4.70640864e-02,
#         1.18866878e+01],
#        [1.18639762e+02, 8.99766496e-01, 1.14535424e+03, 2.56401331e+02,
#         8.89959888e+02, 3.57273473e+01, 8.65335045e-01, 9.49180518e-02,
#         8.01362132e-01, 5.86622969e-03, 9.94397759e-02, 1.91848739e+01,
#         4.00973708e+03, 1.25555010e+03, 1.90237927e+02, 8.05787218e-01,
#         1.12829132e+01],
# ...
